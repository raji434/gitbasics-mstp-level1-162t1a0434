# %%
import matplotlib.pyplot as v
import matplotlib.image as r
image=r.imread('kajal.jpg')
v.imshow(image)

# %%
import matplotlib.pyplot as v
import matplotlib.image as r
image=r.imread('kajal.jpg')
v.imshow(image)
v.colorbar()
